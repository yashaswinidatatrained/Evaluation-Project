# %% [markdown]
# ### Loan_Status

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <b>This dataset includes details of applicants who have applied for loan. The dataset includes details like credit history, loan amount, their income, dependents etc. </b>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/loan_prediction.csv")
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %% [markdown]
# we see there are 614 rows and 13 columns in our dataset.

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ### The description of the datset is:
# #### Features
# 1. Loan_ID - This refer to the unique identifier of the applicant's affirmed purchases
# 2. Gender - This refers to either of the two main categories (male and female) into which applicants are divided on the basis of their reproductive functions
# 3. Married - This refers to applicant being in a state of matrimony
# 4. Dependents - This refres to persons who depends on the applicants for survival
# 5. Education - This refers to number of years in which applicant received systematic instruction, especially at a school or university
# 6. Self_Employed - This refers to applicant working for oneself as a freelancer or the owner of a business rather than for an employer
# 7. Applicant Income - This refers to disposable income available for the applicant's use under State law.
# 8. CoapplicantIncome - This refers to disposable income available for the people that participate in the loan application process alongside the main applicant use under State law.
# 9. Loan_Amount - This refers to the amount of money an applicant owe at any given time.
# 10. Loan_Amount_Term - This refers to the duaration in which the loan is availed to the applicant
# 11. Credit History - This refers to a record of applicant's ability to repay debts and demonstrated responsibility in repaying them.
# 12. Property_Area - This refers to the total area within the boundaries of the property as set out in Schedule.
# #### Target
# 13. Loan_Status - This refres to whether applicant is eligible to be availed the Loan requested.
#
# <b>since our target variable Loan_status is categorical data, we need to build Classification Model.</b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# we see  there are 614 rows and 13 columns in which 4 are float type 8 are object type and 1 integer columns. We need to convert these object to numerical using encoding techniques. We also see there are null values in the dataset, we need to treat those nulls.

# %%
for i in df:
    print(df[i].value_counts())
    print("\n")
# Out:
# LP001002    1
# LP002328    1
# LP002305    1
# LP002308    1
# LP002314    1
#            ..
# LP001692    1
# LP001693    1
# LP001698    1
# LP001699    1
# LP002990    1
# Name: Loan_ID, Length: 614, dtype: int64
#
#
# Male      489
# Female    112
# Name: Gender, dtype: int64
#
#
# Yes    398
# No     213
# Name: Married, dtype: int64
#
#
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64
#
#
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
#
#
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64
#
#
# 2500    9
# 4583    6
# 6000    6
# 2600    6
# 3333    5
#        ..
# 3244    1
# 4408    1
# 3917    1
# 3992    1
# 7583    1
# Name: ApplicantIncome, Length: 505, dtype: int64
#
#
# 0.0       273
# 2500.0      5
# 2083.0      5
# 1666.0      5
# 2250.0      3
#          ...
# 2791.0      1
# 1010.0      1
# 1695.0      1
# 2598.0      1
# 240.0       1
# Name: CoapplicantIncome, Length: 287, dtype: int64
#
#
# ...

# %% [markdown]
# We see that Loan_ID is having 614 unique values which is not useful for prediction so we will drop this Loan_id column

# %%
df.drop("Loan_ID", axis=1, inplace=True)

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
categorical_col=[]
numerical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
    else:
        numerical_col.append(i)
print('Categorical Columns are: ', categorical_col)
print('Numerical Columns are: ', numerical_col)
# Out:
# Categorical Columns are:  ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# Numerical Columns are:  ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %%
df.isnull().sum()
# Out:
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#treating Null values
df['Gender'].fillna(df['Gender'].mode()[0], inplace=True)
df['Married'].fillna(df['Married'].mode()[0], inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0], inplace=True)
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0], inplace=True)
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0], inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0], inplace=True)
df['LoanAmount'].fillna(df['LoanAmount'].median(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# We see there is no null values in our dataset. Next we will check for the description of the dataset.

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  614.000000        614.000000
# mean       5403.459283        1621.245798  145.752443        342.410423
# std        6109.041673        2926.248369   84.107233         64.428629
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2877.500000           0.000000  100.250000        360.000000
# 50%        3812.500000        1188.500000  128.000000        360.000000
# 75%        5795.000000        2297.250000  164.750000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      614.000000
# mean         0.855049
# std          0.352339
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# We see that
# 1. The counts of all the columns are equal.
# 2. The standard deviation of ApplicantIncome and Coapplicant Income is high where LoanAmount,Loan_Amount_Term,Credit_History is having less standard deviation which means data is normal in most of the columns.
# 3. Mean is greater than median in features like ApplicantIncome and Coapplicant Income so data is Right Skewed.
# 4. Mean is less than median in features like LoanAmount,Loan_Amount_Term,Credit_History so data is Left Skewed.
# 5. There is huge difference between 75% and Max values which means there is outliers.

# %% [markdown]
# #### Data Visualization

# %%
df.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Gender'])
print(df['Gender'].value_counts())
plt.show()
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %% [markdown]
# We see there are more males who apply for loan compared to female.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Married'])
print(df['Married'].value_counts())
plt.show()
# Out:
# Yes    401
# No     213
# Name: Married, dtype: int64

# %% [markdown]
# We see there are more candidates who are married compared to unmarried.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Dependents'])
print(df['Dependents'].value_counts())
plt.show()
# Out:
# 0     360
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %% [markdown]
# We see there are 360 independent members and almost equal members who are having 1 and 2 independents and very few are having 3+ independents.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Education'])
print(df['Education'].value_counts())
plt.show()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %% [markdown]
# We see there are more graduates compared to non-graduates.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Self_Employed'])
print(df['Self_Employed'].value_counts())
plt.show()
# Out:
# No     532
# Yes     82
# Name: Self_Employed, dtype: int64

# %% [markdown]
# We see there are very few self employed compared to others.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Property_Area'])
print(df['Property_Area'].value_counts())
plt.show()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %% [markdown]
# We see there are more semiurbans compared to Rural and urban area.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Loan_Status'])
print(df['Loan_Status'].value_counts())
plt.show()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %% [markdown]
# We see there are more members who are eligible for loan and very few are non-eligible for loan. Since its our target variables we need to balance the dataset.

# %%
plt.figure(figsize =(15,15), facecolor = 'pink')
num = 1
for column in numerical_col:
    if num <=6:
        plt.subplot(3,2,num)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize = 10)
        
    num +=1
plt.show()

# %% [markdown]
# We see there are more outliers and skewness in the dataset. so we need to treat outliers and skewness.

# %% [markdown]
# #### Bi-Variate Analysis

# %%
plt.figure(figsize = (5,5))
sns.countplot(df['Gender'],hue=df['Loan_Status'])
plt.show()

# %% [markdown]
# We see there are more males who have applied for Loan and also approved for loan compared to females.

# %%
sns.countplot(df['Dependents'],hue=df['Loan_Status'])
plt.show()

# %% [markdown]
# We see there are more people who are independent and also they have more loan approved also. As the deependents are more the expenses will be more so loan approval is also less.

# %%
sns.countplot(df['Married'],hue=df['Loan_Status'])
plt.show()

# %% [markdown]
# We see there are more who are married and also there are approval is also high may be because of both husband and wife working the income will be high so loan can be approved.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Education'],hue=df['Loan_Status'])
plt.show()

# %% [markdown]
# We see there are more graduates whose approval is high compared to non-graduates.

# %%
plt.figure(figsize = (6,6))
sns.countplot(df['Self_Employed'],hue=df['Loan_Status'])
plt.show()

# %% [markdown]
# We see there are more who are not self-employed and also there loan approval is high may be because of there income is high and expenses will be high for those who are self_employed.

# %%
plt.figure(figsize = (5,5))
sns.catplot(x='Loan_Status',y="ApplicantIncome",data=df,kind='bar')
plt.show()

# %% [markdown]
# We see that for both loan_status ApplicantIncome is almost same.

# %%
sns.catplot(x='Loan_Status',y="CoapplicantIncome",data=df,kind='bar')
plt.show()

# %% [markdown]
# We see that when Loan_status is No their coapplicant income is high and Loan_status is Yes their coapplicant income is low

# %%
sns.catplot(x='Loan_Status',y="Credit_History",data=df,kind='bar')
plt.show()

# %% [markdown]
# We see credit history is high when loan_status is Yes.

# %%
plt.figure(figsize = (6,6))
sns.barplot(x = 'Loan_Amount_Term', y='LoanAmount', data = df)
plt.show()

# %% [markdown]
# We see that when loan_amount_term is with 300 the loan_amount is high.

# %% [markdown]
# #### Multi-Variate Analysis

# %%
sns.pairplot(df,hue="Loan_Status")

# %% [markdown]
# ### Check For Outliers

# %%
plt.figure(figsize =(15,15), facecolor = 'white')
num = 1
for column in numerical_col:
    if num <=9:
        plt.subplot(3,3,num)
        sns.boxplot(data = df[column])
        plt.xlabel(column,fontsize = 10)
        
    num +=1
plt.show()

# %% [markdown]
# We see that there are outliers in all the columns. But credit history has only 2 values its like categorical data so no need to remove outliers in this column.

# %%
feature = df[['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term']]

# %%
#using z_score Method
from scipy.stats import zscore
z = np.abs(zscore(feature))
np.where(z>3) #threshold = 3
features_df=df[(z<3).all(axis=1)]
print(features_df.shape)
print("data_loss =   ", ((df.shape[0]-features_df.shape[0])/df.shape[0])*100)
# Out:
# (577, 12)
# data_loss =    6.026058631921824

# %%
#Using Iqr Method
q1 = feature.quantile(0.25)
q3 = feature.quantile(0.75)

iqr = q3-q1

features_iqr_df = df[~((df <(q1 - 1.5*iqr))| (df>(q3+1.5*iqr))).any(axis=1)]
print(features_iqr_df.shape)
print("data_loss =   ", ((df.shape[0]-features_iqr_df.shape[0])/df.shape[0])*100)
# Out:
# (459, 12)
# data_loss =    25.2442996742671

# %% [markdown]
# We see that there iis huge dataloss in Iqr method compared to z-score. So, we consider df with Z-score method.

# %% [markdown]
# ### Check For Skewness

# %%
features_df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
features_df.skew()
# Out:
# ApplicantIncome      2.148522
# CoapplicantIncome    1.350517
# LoanAmount           1.151525
# Loan_Amount_Term    -2.098806
# Credit_History      -1.976043
# dtype: float64

# %% [markdown]
# We see there is skewness in all the columns but loan_amount_terma and Credit_history are categorical data, so no need to remove skewness.

# %%
from scipy.stats import yeojohnson
features_df['ApplicantIncome'] = yeojohnson(features_df['ApplicantIncome'])[0]
features_df['CoapplicantIncome'] = yeojohnson(features_df['CoapplicantIncome'])[0]
features_df['LoanAmount'] = yeojohnson(features_df['LoanAmount'])[0]

# %%
features_df.skew()
# Out:
# ApplicantIncome      0.027981
# CoapplicantIncome   -0.191876
# LoanAmount           0.048425
# Loan_Amount_Term    -2.098806
# Credit_History      -1.976043
# dtype: float64

# %% [markdown]
# We see that now all the values are in the range below +0.5 to -0.5 except categorical columns.

# %%
categorical_col
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in features_df.columns:
    if features_df[i].dtypes == 'object':
        features_df[i] = le.fit_transform(features_df[i])
features_df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0        11.194697
# 1         1        1           1          0              0        10.799279
# 2         1        1           0          0              1        10.125222
# 3         1        1           0          1              0         9.891003
# 4         1        0           0          0              0        11.236333
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0        10.071991
# 610       1        1           3          0              0        10.622891
# 611       1        1           1          0              0        11.725354
# 612       1        1           2          0              0        11.621649
# 613       0        0           0          0              1        10.799279
#
# ...

# %%
features_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 577 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             577 non-null    int32
#  1   Married            577 non-null    int32
#  2   Dependents         577 non-null    int32
#  3   Education          577 non-null    int32
#  4   Self_Employed      577 non-null    int32
#  5   ApplicantIncome    577 non-null    float64
#  6   CoapplicantIncome  577 non-null    float64
#  7   LoanAmount         577 non-null    float64
#  8   Loan_Amount_Term   577 non-null    float64
#  9   Credit_History     577 non-null    float64
#  10  Property_Area      577 non-null    int32
#  11  Loan_Status        577 non-null    int32
# dtypes: float64(5), int32(7)
# memory usage: 42.8 KB

# %%
for i in features_df:
    print(features_df[i].value_counts())
# Out:
# 1    470
# 0    107
# Name: Gender, dtype: int64
# 1    375
# 0    202
# Name: Married, dtype: int64
# 0    345
# 2     95
# 1     93
# 3     44
# Name: Dependents, dtype: int64
# 0    446
# 1    131
# Name: Education, dtype: int64
# 0    504
# 1     73
# Name: Self_Employed, dtype: int64
# 9.840153     8
# 10.799279    6
# 11.236333    6
# 9.901227     6
# 10.478161    5
#             ..
# 10.571062    1
# 10.248391    1
# 10.736669    1
# 10.547598    1
# 11.621649    1
# Name: ApplicantIncome, Length: 474, dtype: int64
# 0.000000     252
# 10.737991      5
# 10.008159      5
# 10.407008      5
# 10.612043      3
#             ...
# 9.093207       1
# 10.120613      1
# 10.650601      1
# 10.939979      1
# 6.825818       1
# Name: CoapplicantIncome, Length: 274, dtype: int64
# 11.768598    33
# 11.464627    19
# 11.064872    17
# 10.639917    15
# 13.689707    12
#              ..
# 15.992360     1
# 6.750063      1
# 16.014333     1
# 7.331217      1
# 15.401381     1
# ...

# %%
df = features_df

# %%
df
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0           0          0              0        11.194697
# 1         1        1           1          0              0        10.799279
# 2         1        1           0          0              1        10.125222
# 3         1        1           0          1              0         9.891003
# 4         1        0           0          0              0        11.236333
# ..      ...      ...         ...        ...            ...              ...
# 609       0        0           0          0              0        10.071991
# 610       1        1           3          0              0        10.622891
# 611       1        1           1          0              0        11.725354
# 612       1        1           2          0              0        11.621649
# 613       0        0           0          0              1        10.799279
#
# ...

# %% [markdown]
# ### Check for Correlation

# %%
df.corr()
# Out:
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.378997    0.188162   0.045696      -0.006207
# Married            0.378997  1.000000    0.329900   0.024817      -0.015779
# Dependents         0.188162  0.329900    1.000000   0.069814       0.044543
# Education          0.045696  0.024817    0.069814   1.000000      -0.007139
# Self_Employed     -0.006207 -0.015779    0.044543  -0.007139       1.000000
# ApplicantIncome    0.058590 -0.024783    0.105994  -0.176074       0.212260
# CoapplicantIncome  0.234551  0.335820    0.004109   0.049739      -0.087338
# LoanAmount         0.172146  0.181878    0.131772  -0.128715       0.117218
# Loan_Amount_Term  -0.104983 -0.127348   -0.087389  -0.090523      -0.032914
# Credit_History     0.013172  0.019308   -0.020288  -0.075217      -0.016390
# Property_Area     -0.026340  0.010595    0.002327  -0.068596      -0.028253
# ...

# %%
df.corr().sum()
# Out:
# Gender               1.971192
# Married              2.202432
# Dependents           1.786815
# Education            0.551144
# Self_Employed        1.153476
# ApplicantIncome      1.192742
# CoapplicantIncome    1.388399
# LoanAmount           2.030265
# Loan_Amount_Term     0.487519
# Credit_History       1.532555
# Property_Area        0.667185
# Loan_Status          1.625525
# dtype: float64

# %%
plt.figure(figsize = (14,8))
sns.heatmap(df.corr(), linewidths = 0.1, fmt = '0.2f', linecolor = "Black", annot=True, cmap = "Wistia")
plt.show()

# %% [markdown]
# We see that there is both positive and negative correlations in this dataset. Married is having highest correlation with gender, Dependents, CoapplicantIncome. Loan Amount is having better correlation with ApplicantIncome. Our target variable Loan_status is having highest correlaion with credit_history.

# %%
df.corr()['Loan_Status'].sort_values()
# Out:
# Education           -0.092658
# Self_Employed       -0.026525
# LoanAmount          -0.023609
# Loan_Amount_Term    -0.020291
# ApplicantIncome     -0.002484
# Gender               0.017408
# Dependents           0.017872
# Property_Area        0.026507
# CoapplicantIncome    0.079344
# Married              0.089026
# Credit_History       0.560936
# Loan_Status          1.000000
# Name: Loan_Status, dtype: float64

# %%
plt.figure(figsize=(15,5))
df.corr()['Loan_Status'].sort_values(ascending=True).drop(['Loan_Status']).plot(kind='bar',color='green')
plt.title('Correlation')
plt.xlabel('Feature')
plt.ylabel('Loan_Status')
plt.show()

# %% [markdown]
# Here also we see that Credit_History is having highest positive correlation with target Loan_Status.ApplicantIncome is having the lowest correlation.

# %% [markdown]
# Next we will scale the data but we need to divide the dataset into features and labels.

# %% [markdown]
# ### Divide into Features and Label

# %%
x = df.drop(columns = ['Loan_Status'], axis = 1)
y = df['Loan_Status']

# %%
x.shape
# Out:
# (577, 11)

# %%
y.shape
# Out:
# (577,)

# %% [markdown]
# ### Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
sr = StandardScaler()
x = pd.DataFrame(sr.fit_transform(x), columns = x.columns)
x
# Out:
#        Gender   Married  Dependents  Education  Self_Employed  \
# 0    0.477137 -1.362511   -0.723313  -0.541961      -0.380580
# 1    0.477137  0.733939    0.282353  -0.541961      -0.380580
# 2    0.477137  0.733939   -0.723313  -0.541961       2.627567
# 3    0.477137  0.733939   -0.723313   1.845150      -0.380580
# 4    0.477137 -1.362511   -0.723313  -0.541961      -0.380580
# ..        ...       ...         ...        ...            ...
# 572 -2.095835 -1.362511   -0.723313  -0.541961      -0.380580
# 573  0.477137  0.733939    2.293686  -0.541961      -0.380580
# 574  0.477137  0.733939    0.282353  -0.541961      -0.380580
# 575  0.477137  0.733939    1.288020  -0.541961      -0.380580
# 576 -2.095835 -1.362511   -0.723313  -0.541961       2.627567
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0           0.681780          -1.122446    0.000771          0.230853
# 1           0.234783           0.744117    0.000771          0.230853
# ...

# %% [markdown]
# #### Now the dataset is scaled, Next we will check for Multicollinearity

# %% [markdown]
# ### Variance-Inflation-Factor

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values, i) for i in range(len(x.columns))]
vif['Features'] = x.columns

vif
# Out:
#     VIF Values           Features
# 0     1.222762             Gender
# 1     1.416724            Married
# 2     1.168953         Dependents
# 3     1.070347          Education
# 4     1.052465      Self_Employed
# 5     1.761311    ApplicantIncome
# 6     1.589265  CoapplicantIncome
# 7     1.556424         LoanAmount
# 8     1.056624   Loan_Amount_Term
# 9     1.009648     Credit_History
# 10    1.025866      Property_Area

# %% [markdown]
# We see that all the VIF values are within the range i.e., 10 so there is no multicollinearity. Next we will balance the dataset and then train test split data.

# %%
y.value_counts()
# Out:
# 1    398
# 0    179
# Name: Loan_Status, dtype: int64

# %% [markdown]
# we see there is a imbalance in the dataset. So we will balance this using Oversampling Techniques.

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE()
x, y = sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# 1    398
# 0    398
# Name: Loan_Status, dtype: int64

# %% [markdown]
# We see that our dataset is balanced. Next we will build a model.

# %% [markdown]
# #### Train_Test_Split

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.metrics import f1_score, accuracy_score, classification_report, roc_curve, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.svm import SVC

# %%
accuracy = 0
r_state =0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.30, random_state = i)
    log = LogisticRegression()
    log.fit(x_train,y_train)
    y_pred = log.predict(x_test)
    acc = accuracy_score(y_test,y_pred)
    if acc>accuracy:
        accuracy=acc
        r_state = i
print("max accuracy score is ", accuracy , "randomstate = ",r_state)
# Out:
# max aaccuracy score is  0.7615062761506276 randomstate =  124

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.30, random_state = 124)

# %%
x_train.shape
# Out:
# (557, 11)

# %%
x_test.shape
# Out:
# (239, 11)

# %%
y_train.shape
# Out:
# (557,)

# %%
y_test.shape
# Out:
# (239,)

# %%
log = LogisticRegression()
log.fit(x_train,y_train)
log_pred = log.predict(x_test)
log_pred_train = log.predict(x_train)
print("Logistic Regression")
print("Accuracy of train data is  ",accuracy_score(y_train, log_pred_train)*100, "%")
log_accu = accuracy_score(y_test, log_pred) 
print("Accuracy of test data is  ", (log_accu)*100 ,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,log_pred))
print('\n Test Classification Report \n', classification_report(y_test,log_pred))
print("****************************************")
print("\n")

rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
rfc_pred = rfc.predict(x_test)
rfc_pred_train = rfc.predict(x_train)
print("Random Forest Classifier")
print("Accuracy of train data is  ",accuracy_score(y_train, rfc_pred_train)*100, "%")
rfc_accu = accuracy_score(y_test, rfc_pred) 
print("Accuracy of test data is  ", (rfc_accu)*100,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,rfc_pred))
print('\n Test Classification Report \n', classification_report(y_test,rfc_pred))
print("****************************************")
print("\n")

bc = BaggingClassifier()
bc.fit(x_train,y_train)
bc_pred = bc.predict(x_test)
bc_pred_train = bc.predict(x_train)
print("Bagging Classifier")
print("Accuracy of train data is  ",accuracy_score(y_train, bc_pred_train)*100, "%")
bc_accu = accuracy_score(y_test, bc_pred)
print("Accuracy of test data is  ", (bc_accu)*100,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,bc_pred))
print('\n Test Classification Report \n', classification_report(y_test,bc_pred))
print("****************************************")
print("\n")

abc = AdaBoostClassifier()
abc.fit(x_train,y_train)
abc_pred = abc.predict(x_test)
abc_pred_train = abc.predict(x_train)
print("AdaBoost Classifier")
print("Accuracy of train data is  ",accuracy_score(y_train, abc_pred_train)*100, "%")
abc_accu = accuracy_score(y_test, abc_pred)
print("Accuracy of test data is  ", (abc_accu) *100 ,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,abc_pred))
print('\n Test Classification Report \n', classification_report(y_test,abc_pred))
print("****************************************")
print("\n")

gbc = GradientBoostingClassifier()
gbc.fit(x_train,y_train)
gbc_pred = gbc.predict(x_test)
gbc_pred_train = gbc.predict(x_train)
print("Gradient Boosting Classifier")
print("Accuracy of train data is  ",accuracy_score(y_train, gbc_pred_train)*100, "%")
gbc_accu = accuracy_score(y_test, gbc_pred) 
print("Accuracy of test data is  ", (gbc_accu)*100 ,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,gbc_pred))
print('\n Test Classification Report \n', classification_report(y_test,gbc_pred))
print("****************************************")
print("\n")

etc = ExtraTreesClassifier()
etc.fit(x_train,y_train)
etc_pred = etc.predict(x_test)
etc_pred_train = etc.predict(x_train)
print("Extra Trees Classifier")
print("Accuracy of train data is  ",accuracy_score(y_train, etc_pred_train)*100, "%")
etc_accu = accuracy_score(y_test, etc_pred) 
print("Accuracy of test data is  ", (etc_accu)*100, "%")
print("\n Confusion Matrix", confusion_matrix(y_test,etc_pred))
print('\n Test Classification Report \n', classification_report(y_test,etc_pred))
print("****************************************")
print("\n")

dtc = DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc_pred = dtc.predict(x_test)
dtc_pred_train = dtc.predict(x_train)
print("Decision Trees Classifier")
print("Accuracy of train data is  ",accuracy_score(y_train, dtc_pred_train)*100, "%")
dtc_accu = accuracy_score(y_test, dtc_pred) 
print("Accuracy of test data is  ", (dtc_accu)*100 ,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,dtc_pred))
print('\n Test Classification Report \n', classification_report(y_test,dtc_pred))
print("****************************************")
print("\n")

knn = KNN()
knn.fit(x_train,y_train)
knn_pred = knn.predict(x_test)
knn_pred_train = knn.predict(x_train)
print("K-Nearest Neighbors")
print("Accuracy of train data is  ",accuracy_score(y_train, knn_pred_train)*100, "%")
knn_accu = accuracy_score(y_test, knn_pred) 
print("Accuracy of test data is  ", (knn_accu)*100 ,"%")
print("\n Confusion Matrix", confusion_matrix(y_test, knn_pred))
print('\n Test Classification Report \n', classification_report(y_test, knn_pred))
print("****************************************")
print("\n")


svc = SVC()
svc.fit(x_train,y_train)
svc_pred = svc.predict(x_test)
svc_pred_train = svc.predict(x_train)
print("Super-Vector Classification")
print("Accuracy of train data is  ",accuracy_score(y_train, svc_pred_train)*100 , "%")
svc_accu = accuracy_score(y_test, svc_pred) 
print("Accuracy of test data is  ", (svc_accu)*100,"%")
print("\n Confusion Matrix", confusion_matrix(y_test, svc_pred))
print('\n Test Classification Report \n', classification_report(y_test, svc_pred))
print("****************************************")
print("\n")
# Out:
# Logistic Regression
# Accuracy of train data is   69.47935368043088 %
# Accuracy of test data is   76.15062761506276 %
#
#  Confusion Matrix [[ 71  42]
#  [ 15 111]]
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.83      0.63      0.71       113
#            1       0.73      0.88      0.80       126
#
#     accuracy                           0.76       239
#    macro avg       0.78      0.75      0.75       239
# weighted avg       0.77      0.76      0.76       239
#
# ****************************************
#
#
# Random Forest Classifier
# Accuracy of train data is   100.0 %
# Accuracy of test data is   82.42677824267783 %
#
#  Confusion Matrix [[ 93  20]
#  [ 22 104]]
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.81      0.82      0.82       113
#            1       0.84      0.83      0.83       126
#
# ...

# %%
Accuracy = pd.DataFrame({'Models':['Logistic', 'RandomForest Classifier', 'Bagging Classifier', 'AdaBoost Classifier', 'GradientBoosting','ExtraTreesClassifier','DecisionTree', 'Knn','svc'],
                          'Accuracy_score':[log_accu, rfc_accu, bc_accu,abc_accu,gbc_accu,etc_accu,dtc_accu,knn_accu,svc_accu]
                        })
Accuracy
# Out:
#                     Models  Accuracy_score
# 0                 Logistic        0.761506
# 1  RandomForest Classifier        0.824268
# 2       Bagging Classifier        0.794979
# 3      AdaBoost Classifier        0.811715
# 4         GradientBoosting        0.820084
# 5     ExtraTreesClassifier        0.849372
# 6             DecisionTree        0.786611
# 7                      Knn        0.761506
# 8                      svc        0.765690

# %% [markdown]
# ### Cross-Validation Score

# %%
print('\n Logistic Regression \n')
log_score = cross_val_score(log, x, y, cv=5)
print(log_score)
print(np.mean(log_score))
log_diff = (log_accu - log_score.mean())
print(log_diff)
print("====================================\n ")


print('\n Random Forest Classifier \n')
rfc_score = cross_val_score(rfc, x, y, cv=5)
print(rfc_score)
print(np.mean(rfc_score))
rfc_diff = (rfc_accu - rfc_score.mean())
print(rfc_diff)
print("====================================\n ")


print('\n Bagging Classifier \n')
bc_score = cross_val_score(bc, x, y, cv=5)
print(bc_score)
print(np.mean(bc_score))
bc_diff = (bc_accu - bc_score.mean())
print(bc_diff)
print("====================================\n ")


print('\n AdaBoost Classifier \n')
abc_score = cross_val_score(abc, x, y, cv=5)
print(abc_score)
print(np.mean(abc_score))
abc_diff = (abc_accu - abc_score.mean())
print(abc_diff)
print("====================================\n ")

print('\n Gradient Boosting Classifier \n')
gbc_score = cross_val_score(gbc, x, y, cv=5)
print(gbc_score)
print(np.mean(gbc_score))
gbc_diff = (gbc_accu - gbc_score.mean())
print(gbc_diff)
print("====================================\n ")

print('\n ExtraTrees Classifier \n')
etc_score = cross_val_score(etc, x, y, cv=5)
print(etc_score)
print(np.mean(etc_score))
etc_diff = (etc_accu - etc_score.mean())
print(etc_diff)
print("====================================\n ")

print('\n DecisionTree Classifier \n')
dtc_score = cross_val_score(dtc, x, y, cv=5)
print(dtc_score)
print(np.mean(dtc_score))
dtc_diff = (dtc_accu - dtc_score.mean())
print(dtc_diff)
print("====================================\n ")

print('\n K-Neighbors Classifier \n')
knn_score = cross_val_score(knn, x, y, cv=5)
print(knn_score)
print(np.mean(knn_score))
knn_diff = (knn_accu - knn_score.mean())
print(knn_diff)
print("====================================\n ")

print('\n Super Vector Classifier \n')
svc_score = cross_val_score(svc, x, y, cv=5)
print(svc_score)
print(np.mean(svc_score))
svc_diff = (svc_accu - svc_score.mean())
print(svc_diff)
print("====================================\n ")
# Out:
#  Logistic Regression
#
# [0.7        0.72327044 0.6918239  0.71069182 0.71069182]
# 0.7072955974842767
# 0.054210678666350876
# ...
#
#
#  Random Forest Classifier
#
# [0.78125    0.79245283 0.86792453 0.88050314 0.89937107]
# 0.8443003144654089
# -0.020032532038630646
# ...
#
#
#  Bagging Classifier
#
# [0.73125    0.77987421 0.82389937 0.81761006 0.85534591]
# 0.8015959119496856
# -0.006616832451777688
# ...
#
#
#  AdaBoost Classifier
#
# [0.66875    0.6918239  0.76100629 0.81761006 0.79245283]
# 0.7463286163522014
# 0.06538686481934675
# ...
#
#
#  Gradient Boosting Classifier
#
# [0.675      0.72327044 0.8427673  0.83018868 0.77987421]
# 0.7702201257861635
# 0.04986355622220473
# ...
#
#
#  ExtraTrees Classifier
#
# [0.78125    0.81132075 0.87421384 0.89937107 0.88679245]
# 0.8505896226415095
# -0.001217237704270957
# ...
#
#
#  DecisionTree Classifier
#
# [0.74375    0.72955975 0.80503145 0.83018868 0.81761006]
# 0.7852279874213837
# 0.0013828912397042536
# ...
#
#
#  K-Neighbors Classifier
#
# ...

# %%
CV_data = pd.DataFrame({'Models':['Logistic', 'RandomForest Classifier', 'Bagging Classifier', 'AdaBoost Classifier', 'GradientBoosting','ExtraTreesClassifier','DecisionTree', 'Knn','svc'],
                        'Accuracy_score':[log_accu, rfc_accu, bc_accu,abc_accu,gbc_accu,etc_accu,dtc_accu,knn_accu,svc_accu],
                        'Diff_score':[log_diff, rfc_diff, bc_diff,abc_diff,gbc_diff,etc_diff,dtc_diff,knn_diff,svc_diff]
                        })
CV_data
# Out:
#                     Models  Accuracy_score  Diff_score
# 0                 Logistic        0.761506    0.054211
# 1  RandomForest Classifier        0.824268   -0.020033
# 2       Bagging Classifier        0.794979   -0.006617
# 3      AdaBoost Classifier        0.811715    0.065387
# 4         GradientBoosting        0.820084    0.049864
# 5     ExtraTreesClassifier        0.849372   -0.001217
# 6             DecisionTree        0.786611    0.001383
# 7                      Knn        0.761506    0.010225
# 8                      svc        0.765690    0.037035

# %% [markdown]
# We see that Decision Tree Classifier has least difference between accuracy and cv score. So we consider Decision has accurate model and we will try to increase the accuracy by tuning the parameters.

# %% [markdown]
# ### Hyper-Parameter Tuning

# %%
param_grid = {"criterion":['gini','entropy','log_los'], "max_depth":[10,20,30],
              "max_features":['auto','sqrt','log2'], "random_state":[10,30,40]   
             }

# %%
Loan = GridSearchCV(DecisionTreeClassifier(), param_grid, cv=5)
Loan.fit(x_train,y_train)
best_parameters=Loan.best_params_
print(best_parameters)
best_result=Loan.best_score_
print(best_result*100)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'random_state': 40}
# 73.78056628056629

# %%
Loan = ExtraTreesClassifier(criterion='entropy', max_depth = 10, random_state=40, max_features = 'auto')

# %%
Loan.fit(x_train,y_train)
Loan_pred = Loan.predict(x_test)
Loan_accu = accuracy_score(y_test,Loan_pred) * 100
print(f"Accuracy Score of test data is: ",Loan_accu ,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,Loan_pred))
print('\n Test Classification Report \n', classification_report(y_test,Loan_pred))
# Out:
# Accuracy Score of test data is:  81.58995815899581 %
#
#  Confusion Matrix [[ 83  30]
#  [ 14 112]]
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.86      0.73      0.79       113
#            1       0.79      0.89      0.84       126
#
#     accuracy                           0.82       239
#    macro avg       0.82      0.81      0.81       239
# weighted avg       0.82      0.82      0.81       239

# %% [markdown]
# We see that after tuning the parameters using {'criterion': 'entropy', 'max_depth': 10, 'max_features': 'auto', 'random_state': 40} the accuracy has increased to 81.5%. So next we will change the parameters and check for increase in accuracy.

# %%
Loan1 = ExtraTreesClassifier(criterion='entropy', max_depth = 40, random_state=50, max_features = 'auto')

# %%
Loan1.fit(x_train,y_train)
Loan1_pred = Loan1.predict(x_test)
Loan1_accu = accuracy_score(y_test,Loan1_pred) * 100
print(f"Accuracy Score of test data is: ",Loan1_accu ,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,Loan1_pred))
print('\n Test Classification Report \n', classification_report(y_test,Loan1_pred))
# Out:
# Accuracy Score of test data is:  84.51882845188284 %
#
#  Confusion Matrix [[ 96  17]
#  [ 20 106]]
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84       113
#            1       0.86      0.84      0.85       126
#
#     accuracy                           0.85       239
#    macro avg       0.84      0.85      0.84       239
# weighted avg       0.85      0.85      0.85       239

# %% [markdown]
# We see that after tuning the parameters using {'criterion': 'entropy', 'max_depth': 40, 'max_features': 'auto', 'random_state': 50} the accuracy has increased to 84.5% and type1 and type2 errors have been reduced. So next we will change the parameters and check for increase in accuracy.

# %%
Loan2 = ExtraTreesClassifier(criterion='entropy', max_depth = 100, random_state=120, max_features = 'auto')

# %%
Loan2.fit(x_train,y_train)
Loan2_pred = Loan2.predict(x_test)
Loan2_accu = accuracy_score(y_test,Loan2_pred) * 100
print(f"Accuracy Score of test data is: ",Loan2_accu ,"%")
print("\n Confusion Matrix", confusion_matrix(y_test,Loan2_pred))
print('\n Test Classification Report \n', classification_report(y_test,Loan2_pred))
# Out:
# Accuracy Score of test data is:  85.77405857740585 %
#
#  Confusion Matrix [[ 98  15]
#  [ 19 107]]
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            0       0.84      0.87      0.85       113
#            1       0.88      0.85      0.86       126
#
#     accuracy                           0.86       239
#    macro avg       0.86      0.86      0.86       239
# weighted avg       0.86      0.86      0.86       239

# %% [markdown]
# We see that after tuning the parameters using {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'random_state': 120} the accuracy has increased to 85.7% and also type1 and type2 errors have been reduced again we change the parameters and check for increase in accuracy but we could not increase the accuracy.So we consider the parameters <b> {'criterion': 'entropy', 'max_depth': 100, 'max_features': 'auto', 'random_state': 120} </b> of DecisionTreeClassifier model as best and accurate for prediction of the loan_status.

# %% [markdown]
# ### Save the Model

# %%
import joblib
joblib.dump(Loan2 ,"Loan_status_prediction.pkl")
# Out:
# ['Loan_status_prediction.pkl']

# %%
Loan_status_model = joblib.load("Loan_status_prediction.pkl")
result = Loan_status_model.score(x_test,y_test)
print(result)
# Out:
# 0.8577405857740585

# %%
Loan_status_df = pd.DataFrame({'Actual':y_test , 'Predicted':Loan2_pred},columns=['Actual','Predicted'])
Loan_status_df.sample(25)
# Out:
#      Actual  Predicted
# 769       0          0
# 56        1          1
# 725       0          0
# 778       0          0
# 598       0          0
# 738       0          0
# 529       1          1
# 113       1          1
# 62        0          0
# 439       1          1
# 167       1          1
# 780       0          0
# 34        0          0
# 765       0          0
# 243       0          0
# 177       1          1
# 47        1          1
# 623       0          0
# 367       1          1
# 154       0          0
# 692       0          0
# 294       1          1
# 41        1          1
# 109       1          1
# 346       1          1

# %%
# Plot AUC_ROC curve

from sklearn import metrics
fpr,tpr,thresholds = metrics.roc_curve(y_test,Loan2_pred)
roc_auc = metrics.auc(fpr,tpr)
display = metrics.RocCurveDisplay(fpr = fpr, tpr = tpr, roc_auc=roc_auc,estimator_name=Loan2)
display.plot()
